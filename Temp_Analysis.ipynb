# %% [markdown]
# <a href="https://colab.research.google.com/github/mohamedgesso054-sudo/Temp_Analysis/blob/main/Temp_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# !pip install pandas

# %% [markdown]
# #---- Testing Dig  ----

# %%
data = {
    'name' : ['Jan','Feb','Mar','April','May','Jon','Jul','Oqst','Sept'],
    'ages' : [25,26,30,40,50,60,30,43,50],
    'saraly' : [100,200, 300, 400, 500, 600, 700, 800, 1000]
    }

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#     name  ages  saraly
# 0    Jan    25     100
# 1    Feb    26     200
# 2    Mar    30     300
# 3  April    40     400
# 4    May    50     500
# 5    Jon    60     600
# 6    Jul    30     700
# 7   Oqst    43     800
# 8   Sept    50    1000

# %%
data_2 = {
    'ID' : [1,2,3,4],
    'Name' : ['Hussien','Mohamed','Ahmed','Ali'],
    'Sarary' : [1000,2000,3000,4000]
    }
df_2 = pd.DataFrame(data_2)
print(df_2)
# Out:
#    ID     Name  Sarary
# 0   1  Hussien    1000
# 1   2  Mohamed    2000
# 2   3    Ahmed    3000
# 3   4      Ali    4000

# %% [markdown]
# #---- Temp Analysis ----

# %%
data_temp = {
    'Days' : [1, 2, 3, 4, 5, 6, 7],
    'Temp_Sudan' : [22.5, 22.7, 25, 27.3, 26.1, 22.4, 20,],
    'Temp_Nyala' : [30.2, 29, 25, 33.3, 39.7, 35, 28],
    }

# %%
df_3 = pd.DataFrame(data_temp)
print(df_3)
# Out:
#    Days  Temp_Sudan  Temp_Nyala
# 0     1        22.5        30.2
# 1     2        22.7        29.0
# 2     3        25.0        25.0
# 3     4        27.3        33.3
# 4     5        26.1        39.7
# 5     6        22.4        35.0
# 6     7        20.0        28.0

# %%
# Temp Of Sudan

# %%
print(df_3[['Days','Temp_Sudan']])
# Out:
#    Days  Temp_Sudan
# 0     1        22.5
# 1     2        22.7
# 2     3        25.0
# 3     4        27.3
# 4     5        26.1
# 5     6        22.4
# 6     7        20.0

# %%
print(df_3[['Days','Temp_Nyala']])
# Out:
#    Days  Temp_Nyala
# 0     1        30.2
# 1     2        29.0
# 2     3        25.0
# 3     4        33.3
# 4     5        39.7
# 5     6        35.0
# 6     7        28.0

# %%
#Line Plots

# %%
plt.plot(df_3['Days'],df_3['Temp_Sudan'])
plt.show()

# %%
plt.plot(df_3['Days'],df_3['Temp_Nyala'])
plt.show()

# %%
# Scatter Plots

# %%
plt.scatter(df_3['Days'],df_3['Temp_Sudan'])
plt.show()

# %%
# Bar Charts

# %%
plt.bar(df_3['Days'],df_3['Temp_Nyala'])
plt.show()

# %%
# Histograms

# %%
plt.hist(data_temp, bins = 2)
plt.show()

# %%
# x-axis & y-axis

plt.plot(df_3['Days'],df_3['Temp_Sudan'])
plt.xlabel('Days of week')
plt.ylabel('Temperatures in Cell.')

plt.title('Temperatures Degrees in Sudan')
plt.show()

# %%
plt.plot(df_3['Days'],df_3['Temp_Nyala'])
plt.xlabel('Days of week')
plt.ylabel('Temperatures in Cell.')

plt.title('Temperatures Degrees in Nyala')
plt.show()

# %%
# Customization Plots

# %%
# x-axis & y-axis

plt.plot(df_3['Days'],df_3['Temp_Sudan'], marker = '*')
plt.plot(df_3['Days'],df_3['Temp_Nyala'], c = 'r', alpha = 0.4, marker = 'o', ls = '--')

# plt.plot(df_3['Days'],df_3['Temp_Sudan'], lablel = 'Sudan') >> You can add lablel in order to know which color can discrable temp

plt.xlabel('Days of week')
plt.ylabel('Temperatures in Cell.')

plt.title('Temperatures Degrees in Sudan, Nyala')
plt.legend(['Sudan','Nyala'])

plt.show()

# %%
# Subplots

# %%
figure, axes = plt.subplots(1, 2, figsize = (10, 5))

axes[0].plot(df_3['Days'],df_3['Temp_Sudan'], c = 'r')
axes[0].set_title('Temperatures Degrees in Sudan')

axes[1].plot(df_3['Days'],df_3['Temp_Nyala'], c = 'k')
axes[1].set_title('Temperatures Degrees in Nyala')

plt.savefig('temp.png')

plt.show()
